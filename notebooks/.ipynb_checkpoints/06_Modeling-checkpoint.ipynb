# %% [markdown]
# # Description
# Build a classification model using various supervised machine and unsupervised machine learning models learning models and check which model gives you the best accuracy use the following models for supervised machine learning.
#
# 1. Logistic Regression
# 2. Decision Tree
# 3. GaussianNB
# 4. MLPClassifier
#
# Using to reduce the dimensionality of the data:
# 1. PCA
#
#
# Using hyperparameter tuning to improve the accuracy of the models.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

# %%
filename = "../data/processed/flight_df_03.csv"
flight_df = pd.read_csv(
        filename,
        sep=';',
        decimal='.',
        encoding='UTF-8',
    )

# %%
flight_df.drop(columns=["Unnamed: 0.2", 'Unnamed: 0.1', 'Unnamed: 0', 'id', 'cancelled', 'year'], inplace=True)

# %%
flight_df['is_delayed_'] = flight_df['is_delayed'].map({True: 1, False: 0})

# %%
flight_df.drop(columns=["is_delayed"], inplace=True)

# %%
le = LabelEncoder()

def clean_labels_encoder(list_of_labels, df):
    for label in list_of_labels:
        df[label] = le.fit_transform(df[label])
    return df

# clean the labels
list_of_labels = ['op_unique_carrier', 'tail_num', 'dep_time_blk', 'arr_time_blk','distance_agg','manufacture_year_agg','origin_city_name','destination_city_name','date','station','name']
flight_df = clean_labels_encoder(list_of_labels, flight_df)

# show head of the dataset
flight_df.head()
# Out:
# C:\Users\milen\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\milen\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\milen\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
flight_df.describe()
# Out:
#               month  day_of_month   day_of_week  op_unique_carrier  \
# count  6.922924e+06  6.922924e+06  6.922924e+06       6.922924e+06
# mean   6.600261e+00  1.571872e+01  3.936600e+00       8.663070e+00
# std    3.404987e+00  8.758981e+00  1.995456e+00       5.293244e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    4.000000e+00  8.000000e+00  2.000000e+00       4.000000e+00
# 50%    7.000000e+00  1.600000e+01  4.000000e+00       1.100000e+01
# 75%    1.000000e+01  2.300000e+01  6.000000e+00       1.400000e+01
# max    1.200000e+01  3.100000e+01  7.000000e+00       1.600000e+01
#
#            tail_num  op_carrier_fl_num  origin_airport_id  dest_airport_id  \
# count  6.922924e+06       6.922924e+06       6.922924e+06     6.922924e+06
# mean   2.996265e+03       2.629736e+03       1.262924e+04     1.262937e+04
# std    1.669742e+03       1.797696e+03       1.532711e+03     1.532889e+03
# ...

# %%
flight_df.dropna(inplace=True)
# show correlation
flight_df.corr()
# Out:
#                           month  day_of_month  day_of_week  op_unique_carrier  \
# month                  1.000000      0.014679    -0.020734          -0.003070
# day_of_month           0.014679      1.000000    -0.012987           0.010367
# day_of_week           -0.020734     -0.012987     1.000000          -0.000470
# op_unique_carrier     -0.003070      0.010367    -0.000470           1.000000
# tail_num              -0.024556      0.003721     0.008032          -0.072356
# op_carrier_fl_num      0.006259     -0.005471     0.063106           0.287493
# origin_airport_id     -0.011133      0.001362    -0.006044          -0.018674
# dest_airport_id       -0.008102     -0.000553     0.002278           0.027067
# crs_dep_time           0.013229     -0.003810     0.026763           0.042229
# dep_time               0.006646     -0.003008     0.019735           0.054142
# dep_delay             -0.010959      0.006450    -0.000385          -0.015247
# ...

# %%
# show the correlation in a plt figure
def show_correlation(df):
    plt.figure(figsize=(50, 30))
    sns.set(style='whitegrid', context='notebook')
    cols = [0, 1, 2]
    sns.heatmap(df.corr(), annot=True, square=False, cmap='coolwarm')
    plt.show()

# show the correlation
show_correlation(flight_df)

# %%
# split the data into features and target
# target is is_delayed_

X = flight_df.drop(columns=['is_delayed_'])
y = flight_df['is_delayed_']

# %%
# covert the data into 0 - 1 range using minmax scaler

def scale_data(X):
    scaler = MinMaxScaler()
    X_scaler = scaler.fit_transform(X)
    return X_scaler

X_scaler = scale_data(X)
flight_df = pd.DataFrame(X_scaler)

flight_df.head()
# Out:
# C:\Users\milen\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\milen\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\milen\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaler, y, test_size=0.3, random_state=42)

# %%
def separator(count = 50):
    print('-'*count)

def train_model_and_print_accuracy(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)

    # score train and test sets
    scoreTest = model.score(X_train, y_train)
    scoreTrain = model.score(X_test, y_test)

    # predict the test data
    predict_test = model.predict(X_test)

    cm_result = confusion_matrix(y_test, predict_test)
    cr_result = classification_report(y_test,predict_test)
    model_name = str(model).split('(')[0]

    # print model name in blue color
    print('\033[1m' + model_name + '\033[0m')
    # print -----------------------------------
    separator()
    print('Train Score for '+str(model_name)+': ', (scoreTest))
    separator()
    print('Test Score for '+str(model_name)+': ', (scoreTrain))
    separator()
    print('Confusion Matrix for '+str(model_name)+' for test : \n', (cm_result))
    separator()
    print('Classification Report for '+str(model_name)+' for test : \n', str(cr_result))
    separator()

# %%
log_reg = LogisticRegression()
dt = DecisionTreeClassifier(max_depth=3)
gnb = GaussianNB()

# train the models and print the accuracy
models = [log_reg, dt, gnb]

for model in models:
    train_model_and_print_accuracy(model, X_train, y_train, X_test, y_test)
# Out:
# C:\Users\milen\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\milen\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\milen\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
#PCA to reduce the dimensionality of the data
from sklearn.decomposition import PCA

pca = PCA(0.95)

x_pca = pca.fit_transform(X_scaler)

# Show the number of components
x_pca.shape
# Out:
# (752922, 17)

# %%
X_train, X_test, y_train, y_test = train_test_split(x_pca, y, test_size=0.3, random_state=42)

# %%
print('*'*25, 'PCA', '*'*25)
for model in models:
    train_model_and_print_accuracy(model, X_train, y_train, X_test, y_test)
# Out:
# ************************* PCA *************************
# C:\Users\milen\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\milen\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\milen\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %% [markdown]
# Summary of the project:
#
# The aviation data analytics project used several different machine learning models to predict flight delays. Here are the main model results and some notes:
#
# Logistic Regression:
#
# Training Score: 96.60%
# Test Result: 96.71%
# Precision for delays: 97%
# Recall (sensitivity) for delays: 98%
# F1-score for latency: 98%
# The model achieved very good results in both precision and sensitivity.
#
# Decision Tree Classifier:
#
# Training Score: 100%
# Test Result: 100%
# Precision, Recall and F1-score are 100%.
# The Decision Tree model achieved perfect results on the test set, which may suggest overfitting.
#
# Gaussian Naive Bayes:
#
# Training score: 93.42%
# Test Result: 93.37%
# Precision for delays: 99%
# Recall for delays: 92%
# F1-score for latency: 96%
# The model achieved a good result in sensitivity, but its precision for delays is lower than other models.
#
# Summary:
#
# The best result was achieved by the Decision Tree model, achieving a score of 100% on the test set. However, such a result on test data may suggest overfitting, i.e. too good a fit of the model to the training data.
# The Logistic Regression model also performed very well in both precision and sensitivity.
# The Gaussian Naive Bayes model is less precise but still achieved satisfactory results.
#
# As for satisfaction:
#
# It is worth noting that the effectiveness of the model is not the only evaluation criterion. It is also important to understand which factors influence delays and why a given model works the way it does. The Decision Tree model may require further evaluation to avoid overfitting.
#
# The model results after PCA are generally worse than before. This may be due to the fact that PCA reduces the dimensionality of the data, which may lead to the loss of important information, especially if the independent variables have a significant impact on the results.
# All models appear to have difficulty predicting delays (Class 0), focusing on predicting no delays (Class 1). This may be due to class imbalance in the data.
#
# Ideas for the future:
#
# Carry out a more detailed analysis of the factors contributing to flight delays to gain a better understanding of the problem.
# Experiments with other machine learning algorithms and regularization approaches to optimize model results.
# Attempts to balance the dataset if the data is unbalanced to avoid the dominant class influencing the model results.
# Further testing and validation of the models on new, unknown data to verify that they are indeed effective in predicting flight delays in practice.
# It is important to continually improve models and analysis as new data and information become available.
