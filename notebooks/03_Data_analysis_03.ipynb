# %% [markdown]
#  # Description
#  We are aiming to complete the analysis of the data that has been made available to us. This step adds even more information to our initial set. This time we will check, among other things, whether flight delays depend on the route or weather conditions.
#
#   However, before we get to that, you need to configure the notebook properly, just like in the previous steps.

# %%
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sqlalchemy import create_engine
from psycopg2 import connect
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
#  ## Connection to the database

# %%
username = 'postgres'
password = 'password'

host = 'localhost'
database = 'airlines'
port = 5432

# %%
url = f"postgresql://{username}:{password}@{host}:{port}/{database}"

engine = create_engine(url)

# %%
def read_sql_table(table_name):
    file = pd.read_sql("SELECT * FROM" +" " + table_name +';'"", engine)
    return file

# %%
filename = "../data/processed/flight_df_02.csv"
flight_df = pd.read_csv(
        filename,
        sep=';',
        decimal='.',
        encoding='UTF-8',
    )

flight_df
# Out:
#          Unnamed: 0.1  Unnamed: 0       id  month  day_of_month  day_of_week  \
# 0                   0           0        1      1             1            2
# 1                   1           1        2      1             1            2
# 2                   2           2        3      1             1            2
# 3                   3           3        4      1             1            2
# 4                   4           4        5      1             1            2
# ...               ...         ...      ...    ...           ...          ...
# 6922919       6922919     7422040  7422032     12            30            1
# 6922920       6922920     7422041  7422033     12            30            1
# 6922921       6922921     7422043  7422035     12            31            2
# 6922922       6922922     7422044  7422036     12            31            2
# 6922923       6922923     7422045  7422037     12            31            2
#
#         op_unique_carrier tail_num  op_carrier_fl_num  origin_airport_id  ...  \
# 0                      9E   N931XJ               3290              10874  ...
# 1                      OH   N723PS               5495              10874  ...
# 2                      OH   N525EA               5416              10874  ...
# 3                      OH   N706PS               5426              10874  ...
# 4                      OH   N262PS               5440              10874  ...
# ...                   ...      ...                ...                ...  ...
# 6922919                MQ   N818AE               3744              12511  ...
# 6922920                MQ   N821AE               4235              12511  ...
# 6922921                MQ   N245NN               4040              12511  ...
# 6922922                MQ   N806AE               3744              12511  ...
# 6922923                MQ   N854AE               4235              12511  ...
#
#          weather_delay  nas_delay  security_delay  late_aircraft_delay  year  \
# 0                  NaN        NaN             NaN                  NaN  2019
# 1                  NaN        NaN             NaN                  NaN  2019
# 2                  NaN        NaN             NaN                  NaN  2019
# 3                  NaN        NaN             NaN                  NaN  2019
# 4                  NaN        NaN             NaN                  NaN  2019
# ...                ...        ...             ...                  ...   ...
# 6922919            0.0        0.0             0.0                 31.0  2019
# 6922920            NaN        NaN             NaN                  NaN  2019
# 6922921          129.0        0.0             0.0                  0.0  2019
# 6922922            0.0        0.0             0.0                 71.0  2019
# 6922923            NaN        NaN             NaN                  NaN  2019
#
#          is_delayed  is_weekend  distance_agg manufacture_year  \
# 0             False           0    (500, 600]           2008.0
# 1              True           0    (300, 400]           2004.0
# 2             False           0    (300, 400]              NaN
# 3             False           0    (300, 400]           2004.0
# 4             False           0    (300, 400]           2004.0
# ...             ...         ...           ...              ...
# 6922919        True           0    (400, 500]           2002.0
# 6922920       False           0    (300, 400]           2002.0
# 6922921        True           0    (300, 400]           2016.0
# 6922922        True           0    (400, 500]           2001.0
# 6922923       False           0    (300, 400]           2003.0
#
#          manufacture_year_agg
# 0                (2005, 2008]
# 1                (2002, 2005]
# 2                         NaN
# 3                (2002, 2005]
# 4                (2002, 2005]
# ...                       ...
# 6922919          (1999, 2002]
# 6922920          (1999, 2002]
# 6922921          (2014, 2017]
# 6922922          (1999, 2002]
# 6922923          (2002, 2005]
#
# [6922924 rows x 35 columns]

# %% [markdown]
#  # Enriching with  `airport_list`

# %%
airport_list_df_first = read_sql_table('airport_list')

airport_list_df = airport_list_df_first.copy()
airport_list_df
# Out:
#     id  origin_airport_id              display_airport_name  origin_city_name  \
# 0    1              11638               Fresno Air Terminal        Fresno, CA
# 1    2              13342            General Mitchell Field     Milwaukee, WI
# 2    3              13244             Memphis International       Memphis, TN
# 3    4              15096    Syracuse Hancock International      Syracuse, NY
# 4    5              10397                 Atlanta Municipal       Atlanta, GA
# ..  ..                ...                               ...               ...
# 92  93              13198         Kansas City International   Kansas City, MO
# 93  94              10423  Austin - Bergstrom International        Austin, TX
# 94  95              15370               Tulsa International         Tulsa, OK
# 95  96              13303               Miami International         Miami, FL
# 96  97              10693        Myrtle Beach International  Myrtle Beach, SC
#
#                                                  name
# 0                FRESNO YOSEMITE INTERNATIONAL, CA US
# 1                   MILWAUKEE MITCHELL AIRPORT, WI US
# 2                MEMPHIS INTERNATIONAL AIRPORT, TN US
# 3       SYRACUSE HANCOCK INTERNATIONAL AIRPORT, NY US
# 4   ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# ..                                                ...
# 92           KANSAS CITY INTERNATIONAL AIRPORT, MO US
# 93      AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 94     OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US
# 95                 MIAMI INTERNATIONAL AIRPORT, FL US
# 96                          NORTH MYRTLE BEACH, SC US
#
# [97 rows x 5 columns]

# %%
test = airport_list_df.drop_duplicates(subset='origin_airport_id').shape[0]
test == airport_list_df.shape[0]
# Out:
# True

# %%
flight_df = pd.merge(
    left=flight_df,
    right=airport_list_df[['origin_airport_id', 'origin_city_name']],
    how='left',
    on=['origin_airport_id']
)
flight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6922924 entries, 0 to 6922923
# Data columns (total 36 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Unnamed: 0.1          int64
#  1   Unnamed: 0            int64
#  2   id                    int64
#  3   month                 int64
#  4   day_of_month          int64
#  5   day_of_week           int64
#  6   op_unique_carrier     object
#  7   tail_num              object
#  8   op_carrier_fl_num     int64
#  9   origin_airport_id     int64
#  10  dest_airport_id       int64
#  11  crs_dep_time          int64
#  12  dep_time              float64
#  13  dep_delay             float64
#  14  dep_time_blk          object
#  15  crs_arr_time          int64
#  16  arr_time              float64
#  17  arr_delay_new         float64
#  18  arr_time_blk          object
#  19  cancelled             float64
#  20  crs_elapsed_time      float64
#  21  actual_elapsed_time   float64
#  22  distance              float64
#  23  distance_group        int64
#  24  carrier_delay         float64
#  25  weather_delay         float64
#  26  nas_delay             float64
#  27  security_delay        float64
#  28  late_aircraft_delay   float64
#  29  year                  int64
#  30  is_delayed            bool
#  31  is_weekend            int64
#  32  distance_agg          object
#  33  manufacture_year      float64
#  34  manufacture_year_agg  object
#  35  origin_city_name      object
# dtypes: bool(1), float64(14), int64(14), object(7)
# memory usage: 1.8+ GB

# %%
tmp_airport_list_df = airport_list_df.rename(
    columns = {'origin_city_name': 'destination_city_name'})

flight_df = pd.merge(
    left=flight_df,
    right=tmp_airport_list_df[['origin_airport_id', 'destination_city_name']],
    how='left',
    left_on=['dest_airport_id'],
    right_on=['origin_airport_id']
)

flight_df = (flight_df
            .drop(columns='origin_airport_id_y')
            .rename(columns={'origin_airport_id_x': 'origin_airport_id'})
            )

flight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6922924 entries, 0 to 6922923
# Data columns (total 37 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Unnamed: 0.1           int64
#  1   Unnamed: 0             int64
#  2   id                     int64
#  3   month                  int64
#  4   day_of_month           int64
#  5   day_of_week            int64
#  6   op_unique_carrier      object
#  7   tail_num               object
#  8   op_carrier_fl_num      int64
#  9   origin_airport_id      int64
#  10  dest_airport_id        int64
#  11  crs_dep_time           int64
#  12  dep_time               float64
#  13  dep_delay              float64
#  14  dep_time_blk           object
#  15  crs_arr_time           int64
#  16  arr_time               float64
#  17  arr_delay_new          float64
#  18  arr_time_blk           object
#  19  cancelled              float64
#  20  crs_elapsed_time       float64
#  21  actual_elapsed_time    float64
#  22  distance               float64
#  23  distance_group         int64
#  24  carrier_delay          float64
#  25  weather_delay          float64
#  26  nas_delay              float64
#  27  security_delay         float64
#  28  late_aircraft_delay    float64
#  29  year                   int64
#  30  is_delayed             bool
#  31  is_weekend             int64
#  32  distance_agg           object
#  33  manufacture_year       float64
#  34  manufacture_year_agg   object
#  35  origin_city_name       object
#  36  destination_city_name  object
# dtypes: bool(1), float64(14), int64(14), object(8)
# memory usage: 1.9+ GB

# %% [markdown]
#  ## Analysis by airports and routes

# %%
top_airports_origin_df = (flight_df
                          .groupby(by=['origin_airport_id']).size()
                         )
top_airports_origin_df
# Out:
# origin_airport_id
# 10135     4938
# 10136     2234
# 10140    23403
# 10141      732
# 10146     1001
#          ...
# 15897      264
# 15919    13839
# 15991      701
# 16218     1911
# 16869      204
# Length: 359, dtype: int64

# %%
top_airports_destination_df = (flight_df
                          .groupby(by=['dest_airport_id']).size()
                         )
top_airports_destination_df
# Out:
# dest_airport_id
# 10135     4943
# 10136     2233
# 10140    23437
# 10141      732
# 10146     1001
#          ...
# 15897      264
# 15919    13866
# 15991      713
# 16218     1907
# 16869      207
# Length: 359, dtype: int64

# %% [markdown]
#  # Enrichment with weather data

# %%
airport_weather_df_first = read_sql_table('airport_weather')

airport_weather_df = airport_weather_df_first.copy()
airport_weather_df
# Out:
#           id      station                                               name  \
# 0          1  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 1          2  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 2          3  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 3          4  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 4          5  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# ...      ...          ...                                                ...
# 46221  46222  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46222  46223  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46223  46224  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46224  46225  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46225  46226  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
#
#              date   awnd    pgtm  prcp  snow  snwd  tavg  ...  wt09  wesd  \
# 0      2019-01-01   4.70     NaN  0.14   0.0   0.0  64.0  ...   NaN   NaN
# 1      2019-01-02   4.92     NaN  0.57   0.0   0.0  56.0  ...   NaN   NaN
# 2      2019-01-03   5.37     NaN  0.15   0.0   0.0  52.0  ...   NaN   NaN
# 3      2019-01-04  12.08     NaN  1.44   0.0   0.0  56.0  ...   NaN   NaN
# 4      2019-01-05  13.42     NaN  0.00   0.0   0.0  49.0  ...   NaN   NaN
# ...           ...    ...     ...   ...   ...   ...   ...  ...   ...   ...
# 46221  2020-03-27   3.58   146.0  0.21   NaN   NaN   NaN  ...   NaN   NaN
# 46222  2020-03-28   6.93  1535.0  1.29   NaN   NaN   NaN  ...   NaN   NaN
# 46223  2020-03-29  16.55  1408.0  0.02   NaN   NaN   NaN  ...   NaN   NaN
# 46224  2020-03-30  13.42   817.0  0.00   NaN   NaN   NaN  ...   NaN   NaN
# 46225  2020-03-31   3.80   110.0  0.06   NaN   NaN   NaN  ...   NaN   NaN
#
#        wt10  psun  tsun  sn32  sx32  tobs  wt11  wt18
# 0       NaN   NaN   NaN   NaN   NaN   NaN   NaN  None
# 1       NaN   NaN   NaN   NaN   NaN   NaN   NaN  None
# 2       NaN   NaN   NaN   NaN   NaN   NaN   NaN  None
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN  None
# 4       NaN   NaN   NaN   NaN   NaN   NaN   NaN  None
# ...     ...   ...   ...   ...   ...   ...   ...   ...
# 46221   NaN   NaN   NaN   NaN   NaN   NaN   NaN  None
# 46222   NaN   NaN   NaN   NaN   NaN   NaN   NaN  None
# 46223   NaN   NaN   NaN   NaN   NaN   NaN   NaN  None
# 46224   NaN   NaN   NaN   NaN   NaN   NaN   NaN  None
# 46225   NaN   NaN   NaN   NaN   NaN   NaN   NaN  None
#
# [46226 rows x 34 columns]

# %%
airport_weather_df = airport_weather_df[['station', 'name', 'date',
                                         'prcp', 'snow', 'snwd', 'tmax',
                                         'awnd']]

# %%
airport_weather_df = pd.merge(
    left=airport_weather_df,
    right=airport_list_df[['origin_airport_id', 'name']],
    how='inner',
    on='name'
)

# %%
airport_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43394 entries, 0 to 43393
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   station            43394 non-null  object
#  1   name               43394 non-null  object
#  2   date               43394 non-null  object
#  3   prcp               43368 non-null  float64
#  4   snow               29578 non-null  float64
#  5   snwd               29007 non-null  float64
#  6   tmax               43386 non-null  float64
#  7   awnd               43386 non-null  float64
#  8   origin_airport_id  43394 non-null  int64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 3.3+ MB

# %% [markdown]
#  ## Join `airport_weather_df` and `flight_df`

# %%
airport_weather_df['date'] = pd.to_datetime(airport_weather_df['date'])

# %%
flight_df['date'] = (flight_df['year'].astype(str)
                     + '-' + flight_df['month'].astype(str)
                     + '-' + flight_df['day_of_month'].astype(str)
                    )
flight_df['date'] = pd.to_datetime(flight_df['date'])

# %%
flight_df=pd.merge(
    left=flight_df,
    right=airport_weather_df,
    how='left',
    on=['date','origin_airport_id']
)
flight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6922924 entries, 0 to 6922923
# Data columns (total 45 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Unnamed: 0.1           int64
#  1   Unnamed: 0             int64
#  2   id                     int64
#  3   month                  int64
#  4   day_of_month           int64
#  5   day_of_week            int64
#  6   op_unique_carrier      object
#  7   tail_num               object
#  8   op_carrier_fl_num      int64
#  9   origin_airport_id      int64
#  10  dest_airport_id        int64
#  11  crs_dep_time           int64
#  12  dep_time               float64
#  13  dep_delay              float64
#  14  dep_time_blk           object
#  15  crs_arr_time           int64
#  16  arr_time               float64
#  17  arr_delay_new          float64
#  18  arr_time_blk           object
#  19  cancelled              float64
#  20  crs_elapsed_time       float64
#  21  actual_elapsed_time    float64
#  22  distance               float64
#  23  distance_group         int64
#  24  carrier_delay          float64
#  25  weather_delay          float64
#  26  nas_delay              float64
#  27  security_delay         float64
#  28  late_aircraft_delay    float64
#  29  year                   int64
#  30  is_delayed             bool
#  31  is_weekend             int64
#  32  distance_agg           object
#  33  manufacture_year       float64
#  34  manufacture_year_agg   object
#  35  origin_city_name       object
#  36  destination_city_name  object
#  37  date                   datetime64[ns]
#  38  station                object
#  39  name                   object
#  40  prcp                   float64
#  41  snow                   float64
#  42  snwd                   float64
#  43  tmax                   float64
#  44  awnd                   float64
# dtypes: bool(1), datetime64[ns](1), float64(19), int64(14), object(10)
# memory usage: 2.3+ GB

# %%
flight_df.to_csv("../data/processed/flight_df_03.csv",
                sep=';')
